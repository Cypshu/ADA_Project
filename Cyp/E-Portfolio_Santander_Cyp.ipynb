# %% [markdown]
# # E-Portfolio – Santander Customer Transaction Prediction
#
# > **Arbeitsdokument:** Dieses Notebook wird während des gesamten Projekts fortlaufend ergänzt.
# > Nicht bekannte Angaben sind mit `TODO` oder `[PLACEHOLDER]` markiert.
#
# **Modul:** Advanced Data Analytics / Scientific Programming and Data Analysis
# **Semester:** Sommersemester 2026
# **Abgabetermin:** 01.09.2026
# **Portfolio:** Cyprian Sawarzynski

# %% [markdown]
# ## 1. Titel und Zuordnung
#
# - **Thema:** Santander Customer Transaction Prediction
# - **Name:** Cyprian Sawarzynski
# - **Gruppennummer:** 138
# - **Gruppenmitglieder:** Tim Hebestreit (Gruppenleiter), Cyprian Sawarzynski, Angeline Usanayo, Trong Cao
# - **Sprecher/Gruppenleitung:** Tim Hebestreit
# - **Abgabedatei:** `ADA_138_Sawarzynski_Portfolio.pdf`
#
# Dieses individuelle Portfolio dokumentiert meinen eigenen Arbeitsprozess. Gemeinsame Gruppenergebnisse und die Protokolle der Gruppentreffen werden von Tim als Gruppenleiter/Sprecher geführt und bei Bedarf hier referenziert.

# %% [markdown]
# ## 2. Projektüberblick und Fragestellung
#
# ### Datensatz und Aufgabenstellung
#
# Das Projekt behandelt den Datensatz **Santander Customer Transaction Prediction**. Die Daten stammen aus einer Kaggle Competition aus dem Jahr 2019. Auf Basis von Finanztransaktionsmerkmalen soll vorhergesagt werden, ob eine Person eine Transaktion durchführen wird.
#
# - OpenML-Datensatz: ID `45566`
# - Kaggle Competition: [Santander Customer Transaction Prediction](https://www.kaggle.com/c/santander-customer-transaction-prediction)
# - OpenML: [Datensatz 45566](https://www.openml.org/search?type=data&status=active&id=45566)
#
# ### Eigene Forschungsfrage
#
# `[PLACEHOLDER: präzise eigene Forschungsfrage ergänzen, z. B. welche Merkmale und Modelle die Transaktionsvorhersage besonders gut unterstützen.]`
#
# ### Projektziel
#
# Ziel ist die Entwicklung, der Vergleich und die begründete Evaluation mehrerer Machine-Learning-Modelle für die binäre Klassifikationsaufgabe. Die Entscheidungen sollen durch die explorative Datenanalyse (EDA), geeignete Daten-Pipelines, eine passende Metrik sowie dokumentierte Modellvergleiche nachvollziehbar begründet werden.

# %% [markdown]
# ## 3. Individuelles Logbuch
#
# Das Logbuch wird chronologisch geführt. Jeder Eintrag enthält Datum, Titel, Arbeitsschritte, Entscheidungen, Schwierigkeiten/offene Fragen, Zeitaufwand und gegebenenfalls einen Bezug zu einem Gruppentreffen. Auch verworfene Ansätze und Änderungen werden festgehalten.
#
# ### 06.08.2026 – Portfolio-Skelett und Projektauswahl
#
# - Die Bewertungs- und Projektunterlagen wurden gelesen.
# - Als Projektdatensatz wurde Santander Customer Transaction Prediction (OpenML ID 45566) festgehalten.
# - Dieses Notebook als laufendes E-Portfolio wurde angelegt.
# - Die noch unbekannten Angaben wurden als Platzhalter markiert.
# - **Entscheidung:** Das Logbuch wird ab jetzt zeitnah nach jedem relevanten Arbeitsschritt ergänzt.
# - **Zeitaufwand:** `[PLACEHOLDER: Minuten/Stunden eintragen]`
# - **Gruppentreffen:** `[PLACEHOLDER: kein Treffen / Treffen am …]`
# - **Offene Fragen:** genaue Aufgabenverteilung, eigene Forschungsfrage, Modellstrategie und verfügbarer Rechenrahmen.
#
# ---
#
# ### `[PLACEHOLDER: Datum]` – `[PLACEHOLDER: kurzer Titel]`
#
# - **Arbeitsschritte:** `[PLACEHOLDER]`
# - **Ergebnis/Erkenntnis:** `[PLACEHOLDER]`
# - **Entscheidung und Begründung:** `[PLACEHOLDER]`
# - **Verworfene Ansätze oder Schwierigkeiten:** `[PLACEHOLDER]`
# - **Nächster Schritt:** `[PLACEHOLDER]`
# - **Zeitaufwand:** `[PLACEHOLDER]`
# - **Bezug zum Gruppentreffen:** `[PLACEHOLDER]`

# %% [markdown]
# ## 4. Zusammenfassung des Logbuchs
#
# *Dieser Abschnitt wird am Ende aus dem Logbuch entwickelt und auf maximal vier Seiten einschließlich Abbildungen und Tabellen verdichtet.*
#
# ### 4.1 Fragestellung und Ziel
#
# `[PLACEHOLDER: Fragestellung, fachliche Motivation und Ziel der Analyse ausformulieren.]`
#
# ### 4.2 Vorgehen und Methodeneinsatz
#
# `[PLACEHOLDER: Datenzugang, Datentypen, EDA, Umgang mit fehlenden Werten, Train-Test-Aufteilung, Pipelines, Modelle, Learning Curves, Dimensionsreduktion und Hyperparameteroptimierung beschreiben.]`
#
# ### 4.3 Iterationen und begründete Entscheidungen
#
# `[PLACEHOLDER: mindestens mehrere getestete Ansätze/Varianten gegenüberstellen und anhand von Evaluationsergebnissen begründen.]`
#
# ### 4.4 Ergebnisse
#
# `[PLACEHOLDER: zentrale Kennzahlen, Modellvergleich und wichtigste EDA-Befunde eintragen. Abbildungen und Tabellen nummerieren und im Text referenzieren.]`
#
# ### 4.5 Grenzen, Unsicherheiten und Ausblick
#
# `[PLACEHOLDER: Datenqualität, Rechenzeit, Generalisierbarkeit, mögliche Verzerrungen und konkrete nächste Schritte reflektieren.]`

# %% [markdown]
# ## 5. Einschätzung der Gruppenmitglieder
#
# Dieser Abschnitt wird vertraulich behandelt. Für jede Person werden mindestens eine konkrete Stärke und eine konkrete, respektvoll formulierte Schwäche der Zusammenarbeit mit kurzer Begründung ergänzt. Der Fokus liegt auf Arbeitsweise, Kommunikation und Zusammenarbeit.
#
# ### Tim
# `[PLACEHOLDER: Stärke + konkrete Begründung]`
# `[PLACEHOLDER: Entwicklungsfeld/Schwäche + konkrete Begründung]`
#
# ### Ang
# `[PLACEHOLDER: Stärke + konkrete Begründung]`
# `[PLACEHOLDER: Entwicklungsfeld/Schwäche + konkrete Begründung]`
#
# ### Tro
# `[PLACEHOLDER: Stärke + konkrete Begründung]`
# `[PLACEHOLDER: Entwicklungsfeld/Schwäche + konkrete Begründung]`

# %% [markdown]
# ## 6. Ergebnisse der Gruppe
#
# **Hinweis:** Laut Aufgabenstellung ist dieser Abschnitt nur im Portfolio der Sprecherin enthalten. Tim führt als Gruppenleiter die gemeinsame Darstellung.
#
# `[PLACEHOLDER: Falls von Tim freigegeben, hier auf die finale Gruppenzusammenfassung und zentrale gemeinsame Ergebnisse verweisen.]`

# %% [markdown]
# ## 7. Protokoll der Gruppentreffen
#
# **Hinweis:** Laut Aufgabenstellung ist dieser Abschnitt nur im Portfolio der Sprecherin enthalten. Tim führt die Protokolle. Eigene Bezüge zu Treffen werden zusätzlich im individuellen Logbuch dokumentiert.
#
# `[PLACEHOLDER: Verweis auf Tims Protokoll bzw. relevante Treffen ergänzen, sofern erforderlich.]`

# %% [markdown]
# ## 8. Quellen und Hilfsmittel
#
# Zitierstil: `[PLACEHOLDER: z. B. APA 7 oder Harvard verbindlich festlegen]`
#
# - **Waack, J.-M. (2026).** *Bewertungshinweise ADA*, SoSe 2026. Verwendung: Anforderungen und Bewertung des E-Portfolios. Zugriff: Projektunterlagen.
# - **OpenML, Datensatz ID 45566.** *Santander Customer Transaction Prediction*. Verwendung: Datenquelle. Zugriff: `[PLACEHOLDER: Zugriffsdatum ergänzen]`.
# - **Kaggle.** *Santander Customer Transaction Prediction*. Verwendung: Wettbewerbskontext und Datensatzbeschreibung. Zugriff: `[PLACEHOLDER: Zugriffsdatum ergänzen]`.
# - **Python / Jupyter / pandas / NumPy / scikit-learn / matplotlib / seaborn.** Verwendung: Datenanalyse, Visualisierung und Machine Learning. Versionen: `[PLACEHOLDER: tatsächlich verwendete Versionen eintragen]`.
# - **Generative KI.** Verwendung: `[PLACEHOLDER: Tool, Zweck und relevante Prompts transparent dokumentieren]`; Datum: `[PLACEHOLDER: Datum]`.
#
# ### KI- und Tool-Transparenz
#
# Für jeden relevanten Einsatz ergänzen: Datum, Tool/Version, Zweck, verwendeter Prompt bzw. Kurzbeschreibung, Ergebnis und eigene Prüfung des Ergebnisses.

# %% [markdown]
# ## 9. Abschluss-Checkliste
#
# - [ ] Name, Gruppennummer, Thema und Gruppenmitglieder ergänzt
# - [ ] Forschungsfrage und Ziel präzisiert
# - [ ] Logbuch chronologisch und zeitnah geführt
# - [ ] Entscheidungen, verworfene Ansätze, Schwierigkeiten und Iterationen dokumentiert
# - [ ] EDA-Erkenntnisse mit Modellentscheidungen verknüpft
# - [ ] Modelle, Metriken, Pipelines, Learning Curves und Hyperparameter nachvollziehbar beschrieben
# - [ ] Abbildungen/Tabellen nummeriert, beschriftet und im Text interpretiert
# - [ ] Gruppenmitglieder fair und konkret eingeschätzt
# - [ ] Quellen, Softwareversionen und KI-Nutzung vollständig dokumentiert
# - [ ] Notebook ausgeführt und mit `jupyter nbconvert --to pdf` exportiert
# - [ ] PDF nach `ADA_<Gruppennummer>_<Nachname>_Portfolio.pdf` benannt
